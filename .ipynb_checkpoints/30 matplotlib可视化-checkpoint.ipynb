# %% [markdown]
# ## 安装
# pip install matplot lib
#
# 日常工作时，进入matplotlib官网，点首页的[examples](https://matplotlib.org/stable/gallery/index.html#)，里面有很多种图，工作时先找到对应需要的图，点击图打开会，就能看到源代码，模仿即可

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(10))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--')  # 灰色
ax1.hist(randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
plt.plot(randn(50).cumsum(), 'g--')

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]
plt.plot(x,y,linestyle='--', color='#CECECE')

# %%
# Series画图
from pandas import Series, DataFrame
s = Series(randn(10).cumsum(), index=np.arange(0,100, 10))
s.plot()
# Out:
# <AxesSubplot:>

# %%
# DataFrame画图
df = DataFrame(np.random.randn(10, 4).cumsum(0), columns=['a','b','c','d'], index = np.arange(0,100,10))
df.plot()
# Out:
# <AxesSubplot:>
