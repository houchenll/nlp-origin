# %% [markdown]
# 模型：module => loss => 随机梯度下降优化器
# ![%E7%BA%BF%E6%80%A7%E5%9B%9E%E5%BD%92%E6%A8%A1%E5%9E%8B-2.png](attachment:%E7%BA%BF%E6%80%A7%E5%9B%9E%E5%BD%92%E6%A8%A1%E5%9E%8B-2.png)

# %% [markdown]
# ### pytorch 实现深度网络步骤
# 1. 准备数据集
# 2. 设计模型，用于计算预测值
# 3. 构建损失函数和优化器
# 4. 训练周期：前馈(计算损失)+反馈(计算梯度)+更新(权重参数)

# %%
# 使用 mini-batch 风格准备数据集
import torch

x_data = torch.Tensor([[1.0], [2.0], [3.0]])
y_data = torch.Tensor([[2.0], [4.0], [6.0]])
