# %% [markdown]
# dot 矩阵的乘法运算
# trace 计算对角线元素的和
# det 计算矩阵的行列式
# eig 计算方阵的本征值和本征向量
# inv 计算方阵的逆

# %%
import numpy as np

x = np.array([[1,2,3],[4,5,6]])
y = np.array([[1,2],[4,5],[7,8]])
print(x.dot(y))
# Out:
# [[30 36]
#  [66 81]]
